# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("C:/Users/HP/Downloads/kdramas/all_series.csv")
df1.head(1)
# Out:
#    tmdb_id    name original_name  \
# 0   136699  Glitch           글리치
#
#                                             keywords airing_date  \
# 0  friendship, investigation, ufo, miniseries, su...  2022-10-07
#
#                                       poster_img_url  \
# 0  https://image.tmdb.org/t/p/original/dspwDOosid...
#
#                                   background_img_url directors_ids  \
# 0  https://image.tmdb.org/t/p/original/3O5voBAoeQ...       1293597
#
#                                             cast_ids           genres_ids  \
# 0  2067860, 1523043, 1418580, 2239782, 150697, 17...  18, 35, 9648, 10765
#
#    ...  episode_run_time                                           synopsis  \
# 0  ...              54.0  A young woman joins forces with a UFO enthusia...
#
#    popularity average_rating  rating_count  next_episode_to_air  \
# 0     520.913            7.7          22.0                  NaN
#
# ...

# %%
df1 = df1.drop(['original_name','airing_date','background_img_url','number_of_seasons','number_of_episodes','episode_run_time','popularity','average_rating','rating_count','next_episode_to_air','next_episode_air_date','origin_country','networks_ids','production_companies_ids'],axis='columns')
df1.head(1)
# Out:
#    tmdb_id    name                                           keywords  \
# 0   136699  Glitch  friendship, investigation, ufo, miniseries, su...
#
#                                       poster_img_url directors_ids  \
# 0  https://image.tmdb.org/t/p/original/dspwDOosid...       1293597
#
#                                             cast_ids           genres_ids  \
# 0  2067860, 1523043, 1418580, 2239782, 150697, 17...  18, 35, 9648, 10765
#
#                                             synopsis
# 0  A young woman joins forces with a UFO enthusia...

# %%
df1.isnull().sum()
# Out:
# tmdb_id           0
# name              0
# keywords          0
# poster_img_url    0
# directors_ids     0
# cast_ids          0
# genres_ids        0
# synopsis          0
# dtype: int64

# %%
df1 = df1.dropna()

# %%
df1.shape
# Out:
# (131, 8)

# %%
dir_name = pd.read_csv("C:/Users/HP/Downloads/kdramas/people.csv")
dir_name.head(1)
# Out:
#    tmdb_id    name                                          biography  \
# 0  1257661  Lee El  Kim Ji-hyun, better known by her stage name EL...
#
#        place_of_birth    birthday deathday  gender known_for_department  \
# 0  Seoul, South Korea  1982-08-26      NaN     1.0               Acting
#
#    popularity                                    profile_img_url
# 0      10.688  https://image.tmdb.org/t/p/original/cXG6IcCaqt...

# %%
dir_name = dir_name.drop(['biography','place_of_birth','birthday','deathday','gender','known_for_department','popularity','profile_img_url'],axis='columns')
dir_name.head(2)
# Out:
#    tmdb_id         name
# 0  1257661       Lee El
# 1  2097078  Jeon Jin-gi

# %%
x=1257661
dir_name.loc[dir_name['tmdb_id']==x,"name"].item()
# Out:
# 'Lee El'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131 entries, 0 to 1374
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tmdb_id         131 non-null    int64
#  1   name            131 non-null    object
#  2   keywords        131 non-null    object
#  3   poster_img_url  131 non-null    object
#  4   directors_ids   131 non-null    object
#  5   cast_ids        131 non-null    object
#  6   genres_ids      131 non-null    object
#  7   synopsis        131 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 9.2+ KB

# %%
no = df1['directors_ids']
no
# Out:
# 0       1293597
# 1       1182291
# 2       1294471
# 5       1724565
# 6        939147
#          ...
# 1123     117498
# 1153    3527566
# 1323    1764050
# 1330    1902848
# 1374    3192063
# Name: directors_ids, Length: 131, dtype: object

# %%
df1['directors_ids'] = df1['directors_ids'].apply(lambda x: list(x.split(",")))

# %%
df1.head(1)
# Out:
#    tmdb_id    name                                           keywords  \
# 0   136699  Glitch  friendship, investigation, ufo, miniseries, su...
#
#                                       poster_img_url directors_ids  \
# 0  https://image.tmdb.org/t/p/original/dspwDOosid...     [1293597]
#
#                                             cast_ids           genres_ids  \
# 0  2067860, 1523043, 1418580, 2239782, 150697, 17...  18, 35, 9648, 10765
#
#                                             synopsis
# 0  A young woman joins forces with a UFO enthusia...

# %%
def change(num):
    list1=[]
    for i in num:
      list1.append(dir_name.loc[dir_name['tmdb_id']==int(i),"name"].item())
    return list1
#Lee El
#Jeon Jin-gi
list_demo = ['1257661','2097078']
change(list_demo)
# Out:
# ['Lee El', 'Jeon Jin-gi']

# %%
x = df1['directors_ids'][0]
df1['directors_ids'] = df1.directors_ids.apply(change)

# %%
df1.head(3)
# Out:
#    tmdb_id                name  \
# 0   136699              Glitch
# 1    99966  All of Us Are Dead
# 2    93405          Squid Game
#
#                                             keywords  \
# 0  friendship, investigation, ufo, miniseries, su...
# 1  high school, bullying, based on comic, horror,...
# 2  secret organization, challenge, survival, fict...
#
#                                       poster_img_url      directors_ids  \
# 0  https://image.tmdb.org/t/p/original/dspwDOosid...         [Roh Deok]
# 1  https://image.tmdb.org/t/p/original/pTEFqAjLd5...           [JQ Lee]
# 2  https://image.tmdb.org/t/p/original/dDlEmu3EZ0...  [Hwang Dong-hyuk]
#
#                                             cast_ids           genres_ids  \
# 0  2067860, 1523043, 1418580, 2239782, 150697, 17...  18, 35, 9648, 10765
# 1  2125084, 1493898, 2185341, 2074587, 2402531, 1...     10759, 18, 10765
# 2  73249, 1593672, 3194501, 1557181, 1048070, 191...      10759, 9648, 18
#
# ...

# %%
df1['cast_ids'] = df1['cast_ids'].apply(lambda x: list(x.split(",")))

# %%
df1['cast_ids'][0]
# Out:
# ['2067860',
#  ' 1523043',
#  ' 1418580',
#  ' 2239782',
#  ' 150697',
#  ' 1747532',
#  ' 181332',
#  ' 1511024',
#  ' 3138793',
#  ' 1605872',
#  ' 2120094',
#  ' 2758995',
#  ' 2878492',
#  ' 1572347',
#  ' 2003804',
#  ' 939133',
#  ' 2098630',
#  ' 2840538',
#  ' 2124185']

# %%
def change(num):
    list1=[]
    j=0
    for i in num:
        if(j<3):
            list1.append(dir_name.loc[dir_name['tmdb_id']==int(i),"name"].item())
            j +=1
    return list1
#Lee El
#Jeon Jin-gi
list_demo = [2067860, 1523043, 1418580, 2239782]
change(list_demo)
# Out:
# ['Jeon Yeo-been', 'Nana', 'Lee Dong-hwi']

# %%
df1['cast_ids'] = df1.cast_ids.apply(change)

# %%
df1.genres_ids[0]
# Out:
# '18, 35, 9648, 10765'

# %%
gen_name = pd.read_csv("C:/Users/HP/Downloads/kdramas/genres.csv")
gen_name.head()
# Out:
#    tmdb_id                name
# 0       18               Drama
# 1       35              Comedy
# 2     9648             Mystery
# 3    10765    Sci-Fi & Fantasy
# 4    10759  Action & Adventure

# %%
def change(num):
    list1=[]
    for i in num:
        list1.append(gen_name.loc[gen_name['tmdb_id']==int(i),"name"].item())
    return list1
#Lee El
#Jeon Jin-gi
list_demo = [18, 35, 9648, 10765]
change(list_demo)
# Out:
# ['Drama', 'Comedy', 'Mystery', 'Sci-Fi & Fantasy']

# %%
df1['genres_ids'] = df1['genres_ids'].apply(lambda x: list(x.split(",")))

# %%
df1.head()
# Out:
#    tmdb_id                name  \
# 0   136699              Glitch
# 1    99966  All of Us Are Dead
# 2    93405          Squid Game
# 5    67915              Goblin
# 6   106651           Hellbound
#
#                                             keywords  \
# 0  friendship, investigation, ufo, miniseries, su...
# 1  high school, bullying, based on comic, horror,...
# 2  secret organization, challenge, survival, fict...
# 5          romance, super power, past life, immortal
# 6  hell, cult, based on cartoon, supernatural cre...
#
#                                       poster_img_url      directors_ids  \
# 0  https://image.tmdb.org/t/p/original/dspwDOosid...         [Roh Deok]
# 1  https://image.tmdb.org/t/p/original/pTEFqAjLd5...           [JQ Lee]
# 2  https://image.tmdb.org/t/p/original/dDlEmu3EZ0...  [Hwang Dong-hyuk]
# 5  https://image.tmdb.org/t/p/original/c2gon6zbqz...     [Lee Eung-bok]
# 6  https://image.tmdb.org/t/p/original/5NYdSAnDVI...     [Yeon Sang-ho]
#
# ...

# %%
df1['genres_ids'] = df1.genres_ids.apply(change)

# %%
df1.poster_img_url[0]
# Out:
# 'https://image.tmdb.org/t/p/original/dspwDOosidQT85oPDDHMM9zmaLw.jpg'

# %%
df1['synopsis'][0]
# Out:
# 'A young woman joins forces with a UFO enthusiast to investigate her boyfriend’s sudden disappearance and stumbles into a wild conspiracy.'

# %%
df1['synopsis'] = df1['synopsis'].apply(lambda x : list(x.split(" ")))

# %%
df1['keywords'] = df1['keywords'].apply(lambda x : list(x.split(",")))

# %%
df1['keywords'] = df1['keywords'].apply(lambda x : [i.replace(" ","") for i in x])

# %%
df1['cast_ids'] = df1['cast_ids'].apply(lambda x : [i.replace(" ","") for i in x])
df1['directors_ids'] = df1['directors_ids'].apply(lambda x : [i.replace(" ","") for i in x])
df1['genres_ids'] = df1['genres_ids'].apply(lambda x : [i.replace(" ","") for i in x])

# %%
df1['tags'] = df1['synopsis'] + df1['cast_ids'] + df1['directors_ids'] + df1['genres_ids'] + df1['keywords']

# %%
df1['tags'].head(1)
# Out:
# 0    [A, young, woman, joins, forces, with, a, UFO,...
# Name: tags, dtype: object

# %%
new_df = df1[['tmdb_id','name','tags']]

# %%
df1.shape
# Out:
# (131, 9)

# %%
new_df['tags'] = new_df['tags'].apply(lambda x : " ".join(x))
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_9312/3530946481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x : " ".join(x))

# %%
new_df['tags'][0]
# Out:
# 'A young woman joins forces with a UFO enthusiast to investigate her boyfriend’s sudden disappearance and stumbles into a wild conspiracy. JeonYeo-been Nana LeeDong-hwi RohDeok Drama Comedy Mystery Sci-Fi&Fantasy friendship investigation ufo miniseries suspense'

# %%
new_df['tags'] = new_df['tags'].apply(lambda x : x.lower())
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_9312/3679624391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x : x.lower())

# %%
new_df.name[0:10]
# Out:
# 0                         Glitch
# 1             All of Us Are Dead
# 2                     Squid Game
# 5                         Goblin
# 6                      Hellbound
# 7              Business Proposal
# 8     Extraordinary Attorney Woo
# 14                  Little Women
# 20                       My Name
# 21                The Silent Sea
# Name: name, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000, stop_words='english')

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
cv.get_feature_names()
# Out:
# ['000',
#  '05',
#  '10',
#  '100',
#  '13',
#  '15',
#  '18',
#  '1885',
#  '19',
#  '1900s',
#  '1930',
#  '1970',
#  '1975',
#  '1980s',
#  '1987',
#  '1990',
#  '1997',
#  '19th',
#  '20',
#  '2000',
#  '2001',
#  '2002',
#  '2005',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2070',
#  '21',
#  '24',
#  '25',
#  '28',
#  '29',
#  '30',
#  '30s',
#  '31',
#  '33',
#  '35',
#  '350',
#  '40',
#  '41',
#  '49',
#  '55',
#  '5th',
#  '60th',
#  '70',
#  '939',
#  '999',
#  'abandon',
#  'abduct',
#  'abid',
#  'ability',
#  'abl',
#  'absolut',
#  'abuseofpow',
#  'academ',
#  'accept',
#  'access',
#  'accid',
#  'accident',
#  'acclaim',
#  'accomplish',
#  'accus',
#  'achiev',
#  'act',
#  'action',
#  'actor',
#  'actress',
#  'actual',
#  'adapt',
#  'addict',
#  'adequ',
#  'adopt',
#  'adulthood',
#  'adventur',
#  'advers',
#  'ae',
#  'afar',
#  'affect',
#  'affili',
#  'aft',
#  'afterlif',
#  'aftermath',
#  'ag',
#  'age',
#  'agechang',
# ...

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []
    
    for i in text.split():
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
new_df['tags'][0]
# Out:
# 'a young woman join forc with a ufo enthusiast to investig her boyfriend’ sudden disappear and stumbl into a wild conspiracy. jeonyeo-been nana leedong-hwi rohdeok drama comedi mysteri sci-fi&fantasi friendship investig ufo miniseri suspens'

# %%
stem('a young woman joins forces with a ufo enthusiast to investigate her boyfriend’s sudden disappearance and stumbles into a wild conspiracy. jeonyeo-been nana leedong-hwi rohdeok drama comedy mystery sci-fi&fantasy friendship investigation ufo miniseries suspense')
# Out:
# 'a young woman join forc with a ufo enthusiast to investig her boyfriend’ sudden disappear and stumbl into a wild conspiracy. jeonyeo-been nana leedong-hwi rohdeok drama comedi mysteri sci-fi&fantasi friendship investig ufo miniseri suspens'

# %%
new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_9312/3213734980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
similarity.shape
# Out:
# (131, 131)

# %%
similarity[new_df['name']=='Glitch']
# Out:
# array([[1.        , 0.13430383, 0.05647825, 0.14119562, 0.11941629,
#         0.05189993, 0.13430383, 0.0492366 , 0.10874545, 0.12833175,
#         0.12712835, 0.06686508, 0.09869275, 0.08827348, 0.02787473,
#         0.03798686, 0.14770979, 0.12501993, 0.09847319, 0.05647825,
#         0.04747572, 0.09379581, 0.04494666, 0.04494666, 0.09065192,
#         0.08703883, 0.03711348, 0.09697623, 0.07312724, 0.03350126,
#         0.05970814, 0.08843154, 0.16943475, 0.14213381, 0.21212121,
#         0.05723638, 0.11941629, 0.06477503, 0.03191535, 0.10948978,
#         0.06579517, 0.03413944, 0.14119562, 0.03260773, 0.11009638,
#         0.02752409, 0.07460471, 0.05951397, 0.05732252, 0.05574947,
#         0.20483662, 0.03553345, 0.05437272, 0.06030227, 0.09984038,
#         0.10660036, 0.05802589, 0.02594996, 0.09534626, 0.08827348,
#         0.07422696, 0.05802589, 0.05437272, 0.07242068, 0.0527535 ,
#         0.04222003, 0.02901294, 0.11447276, 0.11396058, 0.02580699,
# ...

# %%
index = [new_df['name']=='Glitch']
similarity[index]
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_9312/2868633298.py:2: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   similarity[index]
# array([[1.        , 0.13430383, 0.05647825, 0.14119562, 0.11941629,
#         0.05189993, 0.13430383, 0.0492366 , 0.10874545, 0.12833175,
#         0.12712835, 0.06686508, 0.09869275, 0.08827348, 0.02787473,
#         0.03798686, 0.14770979, 0.12501993, 0.09847319, 0.05647825,
#         0.04747572, 0.09379581, 0.04494666, 0.04494666, 0.09065192,
#         0.08703883, 0.03711348, 0.09697623, 0.07312724, 0.03350126,
#         0.05970814, 0.08843154, 0.16943475, 0.14213381, 0.21212121,
#         0.05723638, 0.11941629, 0.06477503, 0.03191535, 0.10948978,
#         0.06579517, 0.03413944, 0.14119562, 0.03260773, 0.11009638,
# ...

# %%
def recommend(kdrama):
    drama_index = new_df[new_df['name']== '49 Days'].index[0]
    distances = similarity[drama_index]
    drama_list = sorted(list(enumerate(distances)),reverse = True, key = lambda x : x[1])[1:6]
    
    for i in drama_list:
        print(new_df.iloc[i[0]]["name"])

# %%
#recommend('All of Us Are Dead')
#recommend('Business Proposal')
#recommend('Goblin')
new_df[new_df['name']=='49 Days']
# Out:
#      tmdb_id     name                                               tags
# 388    38861  49 Days  shin ji hyun wa enjoy absolut bliss as she wa ...

# %%
index = new_df[new_df['name'] == '49 Days'].index[0]
index
# Out:
# 388

# %%
# !pip install streamlit
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mysql-connector-python 8.0.30 requires protobuf<=3.20.1,>=3.11.0, but you have protobuf 3.20.3 which is incompatible.
# ...
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19583 sha256=b7e3311e469cda9d1d001043db305a62a9703e47960feb94b97d5e7487e381a8
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\2d\f0\a8\1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# ...

# %%
images = df1.drop(['keywords','directors_ids','cast_ids','genres_ids','synopsis','tags'],axis='columns')
images
# Out:
#       tmdb_id                 name  \
# 0      136699               Glitch
# 1       99966   All of Us Are Dead
# 2       93405           Squid Game
# 5       67915               Goblin
# 6      106651            Hellbound
# ...       ...                  ...
# 1123   118931     How to Be Thirty
# 1153   199923       Ocean Likes Me
# 1323    78011    Amnok River Flows
# 1330   112486              Big Bet
# 1374   195743  Recipe for Farewell
#
#                                          poster_img_url
# 0     https://image.tmdb.org/t/p/original/dspwDOosid...
# 1     https://image.tmdb.org/t/p/original/pTEFqAjLd5...
# 2     https://image.tmdb.org/t/p/original/dDlEmu3EZ0...
# 5     https://image.tmdb.org/t/p/original/c2gon6zbqz...
# 6     https://image.tmdb.org/t/p/original/5NYdSAnDVI...
# ...                                                 ...
# 1123  https://image.tmdb.org/t/p/original/3fqu5NZEpN...
# 1153  https://image.tmdb.org/t/p/original/brjI8zYGLs...
# ...

# %%
index = images[images['name'] == '49 Days']
index
# Out:
#      tmdb_id     name                                     poster_img_url
# 388    38861  49 Days  https://image.tmdb.org/t/p/original/wBwDrV7HFK...

# %%
new_df.head(1)
# Out:
#    tmdb_id    name                                               tags
# 0   136699  Glitch  a young woman join forc with a ufo enthusiast ...

# %%
similarity.shape
# Out:
# (131, 131)

# %%
import pickle
pickle.dump(new_df,open('kdrama_list.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))

# %%
pickle.dump(images,open('data.pkl','wb'))

# %%
images.head(1)
# Out:
#    tmdb_id    name                                     poster_img_url
# 0   136699  Glitch  https://image.tmdb.org/t/p/original/dspwDOosid...

# %%
images[images['name']=='Glitch']['poster_img_url']
# Out:
# 0    https://image.tmdb.org/t/p/original/dspwDOosid...
# Name: poster_img_url, dtype: object

# %%
images['title'] = images['name']
images.head(1)
# Out:
#    tmdb_id    name                                     poster_img_url   title
# 0   136699  Glitch  https://image.tmdb.org/t/p/original/dspwDOosid...  Glitch

# %%
images = images.drop(['name'],axis='columns')
images
# Out:
#       tmdb_id                                     poster_img_url  \
# 0      136699  https://image.tmdb.org/t/p/original/dspwDOosid...
# 1       99966  https://image.tmdb.org/t/p/original/pTEFqAjLd5...
# 2       93405  https://image.tmdb.org/t/p/original/dDlEmu3EZ0...
# 5       67915  https://image.tmdb.org/t/p/original/c2gon6zbqz...
# 6      106651  https://image.tmdb.org/t/p/original/5NYdSAnDVI...
# ...       ...                                                ...
# 1123   118931  https://image.tmdb.org/t/p/original/3fqu5NZEpN...
# 1153   199923  https://image.tmdb.org/t/p/original/brjI8zYGLs...
# 1323    78011  https://image.tmdb.org/t/p/original/br5bVmklHe...
# 1330   112486  https://image.tmdb.org/t/p/original/b7wLXWOdey...
# 1374   195743  https://image.tmdb.org/t/p/original/2xbkLAQnNF...
#
#                     title
# 0                  Glitch
# 1      All of Us Are Dead
# 2              Squid Game
# 5                  Goblin
# 6               Hellbound
# ...

# %%
pickle.dump(images,open('data_drama.pkl','wb'))
